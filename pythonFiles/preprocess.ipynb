# %% [markdown]
# Importing the needed packages this can be extended as needed

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Load dataset iris

# %%
# loading the data set and add headers to make it more readable 
data = pd.read_csv("../DataSet/iris.data", 
header=None, 
names=["sepal_length", 
        "sepal_width", 
        "petal_length", 
        "petal_width", 
        "species"])

# printing head or the first few rows to see if it works
data.head()

# %% [markdown]
# check if petal length > 1.5 → print “Large petal”
# else “Small petal.”

# %%
def larget_shotest_petal():
    target_length = 1.5
    # calling the column thats being used
    length_column = data['petal_length']
    # stores metadata aka the first row in the data set 
    largest_pettle = length_column[0]

    # loop through every column of the data set
    for i in length_column:
        # uses the colum name to get the length column
        if i >= target_length:
            print(f'{i} large pettle')
        else:
            print(f'{i} small pettle')

        # seeing what is the largst and smallest variable the prining it
        if i > largest_pettle:
            largest_pettle = i

    print(f'the largest pettle is: {largest_pettle}')
        


larget_shotest_petal()

# %% [markdown]
# Loops: Iterate through a list of species and print them
